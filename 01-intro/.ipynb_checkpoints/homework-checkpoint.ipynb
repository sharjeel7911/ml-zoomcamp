# %%
import numpy as np
import pandas as pd

print("Numpy Version: ", np.__version__)
print("Pandas Version: ", pd.__version__)
# Out:
# Numpy Version:  2.5.3
# Pandas Version:  3.0.5

# %%
df = pd.read_csv("/home/shar/0repos/ai/ml-zoomcamp/01-intro/data/car_fuel_efficiency_2026.csv")

df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
import os
os.getcwd()
# Out:
# '/home/shar/0repos/ai/ml-zoomcamp/!/01-intro/notebooks'
